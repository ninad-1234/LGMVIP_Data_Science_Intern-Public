# %% [markdown]
# <a href="https://colab.research.google.com/github/ninad-1234/LGMVIP_Data_Science_Intern-Public/blob/main/Task_2_Image_to_Pencil_Sketch_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Image to Pencil Sketch with Python**

# %%
import cv2
from IPython.display import Image
from google.colab.patches import cv2_imshow
# imported required libraries successfully

# %% [markdown]
# ## **Image Loading**

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-9071370e-4ee7-43de-918f-1a4f2a2e3cf7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9071370e-4ee7-43de-918f-1a4f2a2e3cf7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tiger.jpg to tiger.jpg

# %%
image = cv2.imread("tiger.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F1910C6D910>

# %% [markdown]
# **Grayscale Image**

# %%
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# here the original photo converted to grey scale
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7F1910BF2AD0>

# %% [markdown]
# **Invert Image**

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
# invert the values of color code
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7F1910B7BA90>

# %% [markdown]
# **Blur Image**

# %%
blurred = cv2.GaussianBlur(inverted_image,(21,21),0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7F1910BF2CD0>

# %% [markdown]
# **Inverted Blur Image**

# %%
inverted_blurred = 255 - blurred
cv2_imshow(inverted_blurred)
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7F1910B80D10>

# %% [markdown]
# # **Pencil Sketch**

# %%
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7F1910B7BD50>
