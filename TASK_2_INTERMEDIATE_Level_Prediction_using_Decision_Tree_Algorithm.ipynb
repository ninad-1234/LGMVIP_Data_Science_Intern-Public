# %% [markdown]
# <a href="https://colab.research.google.com/github/ninad-1234/LGMVIP_Data_Science_Intern-Public/blob/main/TASK_2_INTERMEDIATE_Level_Prediction_using_Decision_Tree_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Prediction using Decision Tree Algorithm**

# %% [markdown]
# Importing required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
# importing the required libraries

# %% [markdown]
# Iris Dataset Uploaded

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-d780276b-cfe9-4760-9bf5-d71845a1e026" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d780276b-cfe9-4760-9bf5-d71845a1e026">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris.csv to Iris.csv

# %%
import io
iris = pd.read_csv(io.BytesIO(data_to_load['Iris.csv']))
# storing WHole data in variable

# %% [markdown]
# Exploring Dataset

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# Slicing Dataset based on float data type and species

# %%
F = iris[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']].values
F[0:10]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1]])

# %%
S = iris['Species']
S[0:10]
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# 5    Iris-setosa
# 6    Iris-setosa
# 7    Iris-setosa
# 8    Iris-setosa
# 9    Iris-setosa
# Name: Species, dtype: object

# %% [markdown]
# Differentiating Data for Training and Testing

# %%
from sklearn.model_selection import train_test_split
X_trainset, X_testset, Y_trainset, Y_testset = train_test_splittrain_X, test_X, train_y, test_y= train_test_split(F,S, test_size=0.3, random_state=0)

# %%
SpeciesTree = DecisionTreeClassifier(criterion = 'entropy', max_depth = 8)
SpeciesTree
# DecisionTreeClassifier is used measure the quality of a split
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=8, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
SpeciesTree.fit(X_trainset, Y_trainset)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=8, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# Precition

# %%
Predict_tree = SpeciesTree.predict(X_testset)

# %% [markdown]
# Testing Prediction

# %%
print(Predict_tree [0:10])
print(Y_testset[0:10])
# Out:
# ['Iris-virginica' 'Iris-versicolor' 'Iris-setosa' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor']
# 114     Iris-virginica
# 62     Iris-versicolor
# 33         Iris-setosa
# 107     Iris-virginica
# 7          Iris-setosa
# 100     Iris-virginica
# 40         Iris-setosa
# 86     Iris-versicolor
# 76     Iris-versicolor
# 71     Iris-versicolor
# Name: Species, dtype: object

# %% [markdown]
# Accuracy Evaluation

# %%
from sklearn import metrics
print("Accuracy percentage : ",metrics.accuracy_score(Y_testset, Predict_tree)*100, "%")
# prediction accuracy 97
# Out:
# Accuracy percentage :  97.77777777777777 %

# %% [markdown]
# VISUALIZATION Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
C = iris.columns[1:10]
SP = iris["Species"].unique().tolist()
SpeciesTree.fit(F,S)
fig, axes = plt.subplots(nrows = 1,ncols = 1, figsize = (10,10), dpi =300)
tree.plot_tree(SpeciesTree,feature_names = C, class_names = SP, filled = True);

# %% [markdown]
# CHecking Prediction with Some Input

# %%
input_set = [[5.4,3.9,1.7,0.4]]

Prediction= SpeciesTree.predict(input_set)

# %%
Prediction
# Out:
# array(['Iris-setosa'], dtype=object)

# %% [markdown]
# Got correct Prediction !!!!
